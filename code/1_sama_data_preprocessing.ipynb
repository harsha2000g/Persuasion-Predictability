# %% [markdown]
# #### Imports

# %%
import pandas as pd

# %% [markdown]
# #### Constants

# %%
DATA_FILE = "data/metrics.csv"

# %% [markdown]
# #### Load file

# %%
data = pd.read_csv(DATA_FILE)

# %% [markdown]
# ### Retrieve the metrics as features

# %%
# Read a string column of a pandas dataframe as dictionary
tmp = pd.DataFrame(data['metrics'].apply(eval).to_list())
data = pd.concat([data, tmp], axis=1).drop('metrics', axis=1)

# %% [markdown]
# #### Feature Engineering

# %% [markdown]
#  Convert the columns of `concreteness`, `argument_type` into a boolean column instead of text column

# %%
data['concreteness'] = data['concreteness'] == 'concrete'
data['argument_type'] = data['argument_type'] == 'logical'

# %% [markdown]
# Convert 'Yes/No' feature cols into standard format
# `cols = ['framing', 'priming', 'hedging', 'pronoun_use', 'active_tense']`

# %%
cols = ['framing', 'priming', 'hedging', 'pronoun_use', 'active_tense']
for col in cols:
    data[col] = data[col].apply(lambda x: str(x).replace(".", "").strip().capitalize())

# %% [markdown]
# Convert these Yes/No columns into Boolean columns

# %%
# If value = "Yes" then 1, else 0
for col in cols:
    data[col] = data[col] == 'Yes'

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# Out:
#          worker_id                                              claim  \
# 0     PQVTZECGNK3K  Governments and technology companies must do m...
# 1     3KTT9HNPV9WX  Governments and technology companies must do m...
# 2     M76GMRF46C69  Cultured/lab-grown meats should be allowed to ...
# 3     3W4KKCTPTP7R  Social media companies should be required to l...
# 4     QQDKMRY3HRXJ  Employers should be allowed to monitor employe...
# ...            ...                                                ...
# 3934  TGDTTDPMKKYP                        Apples are a type of fruit.
# 3935  NRXARJZMTQJP  Gravity causes objects to fall towards the earth.
# 3936  HPAKN7WV46GQ  The capital city of the nation of France locat...
# 3937  YZ2DTEYJM6VF             Water is a liquid at room temperature.
# 3938  FM74X4R6J76N  Water transitions from a liquid to solid state...
#
#                                                argument          source  \
# ...
